# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
phool= sns.load_dataset("iris")
phool

#draw a line plot
sns.barplot(x="species", y="sepal_width", data=phool)
plt.title("Phoolon ka Plot")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
phool= sns.load_dataset("iris")
phool

#draw a line plot
sns.barplot(x="species", y="petal_length", data=phool)
plt.title("Phoolon ka Plot")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
kashti1= sns.load_dataset("titanic")
kashti1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
kashti1= sns.load_dataset("titanic")
kashti1

#draw a line plot
sns.barplot(x="sex", y="survived", hue="who", data=kashti1, order=["female", "male"])
plt.title("Death ratio")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
kashti1= sns.load_dataset("titanic")
kashti1

#draw a line plot
sns.barplot(x="sex", y="survived", hue="who", data=kashti1, order=["female", "male"], color="brown")
plt.title("Death ratio")
plt.show()
# Out:
# C:\Users\technezo\AppData\Local\Temp\ipykernel_8312\701071692.py:9: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:brown'` for the same effect.
#
#   sns.barplot(x="sex", y="survived", hue="who", data=kashti1, order=["female", "male"], color="brown")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
kashti1= sns.load_dataset("titanic")
kashti1

#draw a line plot
sns.barplot(x="sex", y="survived", hue="who", data=kashti1, order=["female", "male"], color="brown", ci=None)
plt.title("Death ratio")
plt.show()
# Out:
# C:\Users\technezo\AppData\Local\Temp\ipykernel_8312\4223535769.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="sex", y="survived", hue="who", data=kashti1, order=["female", "male"], color="brown", ci=None)
# C:\Users\technezo\AppData\Local\Temp\ipykernel_8312\4223535769.py:9: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:brown'` for the same effect.
#
#   sns.barplot(x="sex", y="survived", hue="who", data=kashti1, order=["female", "male"], color="brown", ci=None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
kashti1= sns.load_dataset("titanic")
kashti1

#draw a line plot
sns.barplot(x="sex", y="survived", hue="who", data=kashti1, order=["female", "male"], color="brown",
           palette="deep")
plt.title("Death ratio")
plt.show()

# %%
import seaborn as sns
import numpy
import matplotlib.pyplot as plt

# load dataset
kashti1= sns.load_dataset("titanic")
kashti1

#draw a line plot
sns.barplot(x="class", y="fare", hue="sex", data=kashti1, estimator= median)
plt.title("Death ratio")
plt.show()

# %%
import seaborn as sns
import numpy
import matplotlib.pyplot as plt

# load dataset
kashti1= sns.load_dataset("titanic")
kashti1

#draw a line plot
sns.barplot(x="class", y="fare", hue="sex", data=kashti1, estimator= median, saturation=0.5)
plt.title("Death ratio")
plt.show()

# %%
# horizontal plot
import seaborn as sns
import numpy
import matplotlib.pyplot as plt

# load dataset
kashti1= sns.load_dataset("titanic")
kashti1

#draw a line plot
sns.barplot(x="fare", y="class", hue="sex", data=kashti1, estimator= median, saturation=1)
plt.title("Death ratio")
plt.show()

# %%
# import the required libraries
import seaborn as sns
import matplotlib.pyplot as plt

# read the titanic csv file
# from seaborn library
kashti2= sns.load_dataset("titanic")

sns.barplot(x="class", y= "fare", data=kashti2,
           linewidth= 3, facecolor=(0.5,0.3,0.2,0.2),
           errcolor=".5", edgecolor="0")
# Out:
# C:\Users\technezo\AppData\Local\Temp\ipykernel_5628\2432818877.py:9: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '.5'}` instead.
#
#   sns.barplot(x="class", y= "fare", data=kashti2,
# <Axes: xlabel='class', ylabel='fare'>
